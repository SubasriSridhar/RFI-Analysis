# %%
import pandas as pd
import seaborn as sns
df=pd.read_csv('F:\\RFM_unmelted.csv')
del df['Unnamed: 0']
df.head()
# Out:
#                      userid  Cluster  app_opened_perday_median  \
# 0  5406ceb7eff6145a1a5d347a        1                       2.0
# 1  5406e882eff6145a1a5d3488        1                       6.0
# 2  5436fbffd315b01a0f40aa9f        3                       3.5
# 3  5437b5bf628b54036528af52        2                       8.0
# 4  5437bd7b628b54036528af5a        0                       2.0
#
#    avg_duration_mins  recency_in_days
# 0          30.739639             65.0
# 1           7.578418              9.0
# 2         199.300004             61.0
# 3           6.490540             72.0
# 4           6.299999            353.0

# %%
import matplotlib.pyplot as plt 
g=sns.FacetGrid(df, hue="Cluster",col="Cluster")
g=g.map(plt.hist, "recency_in_days")

# %%
import matplotlib.pyplot as plt 
g=sns.FacetGrid(df, hue="Cluster",col="Cluster")
g=g.map(plt.hist, "app_opened_perday_median")

# %%
import matplotlib.pyplot as plt 
g=sns.FacetGrid(df, hue="Cluster",col="Cluster")
g=g.map(plt.hist, "avg_duration_mins")

# %%
sns.boxplot(x="Cluster", y="recency_in_days", data=df)

# %%
sns.boxplot(x="Cluster", y="avg_duration_mins", data=df)

# %%
sns.boxplot(x="Cluster", y="app_opened_perday_median", data=df)
